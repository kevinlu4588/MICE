# %%
import os
import torch
import numpy as np
from safetensors.torch import load_file
from diffusers import StableDiffusionPipeline, UNet2DConditionModel
from PIL import Image, ImageDraw, ImageFont
import matplotlib.pyplot as plt
from pathlib import Path
import json
import argparse

# %%
erased_pipe = StableDiffusionPipeline.from_pretrained("/share/u/kevin/erasing/models/7_inpainting_erasure_esd_Van_Gogh")
# Out:
# Loading pipeline components...: 100%|██████████| 6/6 [00:07<00:00,  1.21s/it]

# %%
erased_pipe.to('cuda')
plt.imshow(erased_pipe("a painting int eh style of van gogh").images[0])
# Out:
# 100%|██████████| 50/50 [00:06<00:00,  8.15it/s]

# %%
plt.imshow(erased_pipe("a car").images[0])
# Out:
# ...
# 100%|██████████| 50/50 [00:06<00:00,  8.10it/s]

# %%
plt.imshow(erased_pipe("a dog").images[0])
# Out:
# 100%|██████████| 50/50 [00:06<00:00,  8.08it/s]

# %%
erased_pipe.to('cuda')
plt.imshow(erased_pipe("starry night by van gogh").images[0])
# Out:
# 100%|██████████| 50/50 [00:06<00:00,  8.05it/s]

# %%
erased_pipe.to('cuda')
plt.imshow(erased_pipe("a painting").images[0])
# Out:
# 100%|██████████| 50/50 [00:06<00:00,  8.06it/s]

# %%
erased_pipe.to('cuda')
plt.imshow(erased_pipe("a painting the style of picasso").images[0])
# Out:
# 100%|██████████| 50/50 [00:06<00:00,  8.02it/s]

# %%
erased_pipe.to('cuda')
plt.imshow(erased_pipe("self portrait by picasso").images[0])
# Out:
# 100%|██████████| 50/50 [00:06<00:00,  8.02it/s]

# %%
erased_pipe.to('cuda')
plt.imshow(erased_pipe("a painting int eh style of van gogh").images[0])
